# %%
#! pip install pyarrow datasets transformers sacrebleu torch sentencepiece transformers[sentencepiece]
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /gdrive

# %%
import os
import pandas as pd

import torch
import transformers
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from datasets import load_dataset, load_metric
import numpy as np

# %%
# !nvcc --version
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda') 
os.environ["WANDB_DISABLED"]="true" 
model_checkpoint = "Helsinki-NLP/opus-mt-ko-en"

# %%
# load preprocessed dataset
# write lines, where line is = {"translation": {"ko": ko_sentence, "en": en_sentence}}
raw_datasets = load_dataset('json', data_files= {'train':'/content/drive/MyDrive/nlp_study/rawdataset/train_ko_en_dataset.json',
                                                 'validation':'/content/drive/MyDrive/nlp_study/rawdataset/validation_ko_en_dataset.json',
                                                 'test':'/content/drive/MyDrive/nlp_study/rawdataset/test_ko_en_dataset.json'})
# Out:
# Using custom data configuration default-60be4a8afb0af00f
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-60be4a8afb0af00f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde...
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-60be4a8afb0af00f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 378778
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 1241
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 1241
#     })
# })

# %%
metric = load_metric("sacrebleu")
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/822k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.64M [00:00<?, ?B/s]

# %%
prefix = ""
max_input_length = 128
max_target_length = 128
source_lang = "ko"
target_lang = "en"
def preprocess_function(examples):
    inputs = [prefix + ex[source_lang] for ex in examples["translation"]]
    targets = [ex[target_lang] for ex in examples["translation"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)
    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-60be4a8afb0af00f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde/cache-66f80348d2bb4450.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-60be4a8afb0af00f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde/cache-30a64e95562d6edc.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/json/default-60be4a8afb0af00f/0.0.0/c90812beea906fcffe0d5e3bb9eba909a80a998b5f88e9f8acbd320aa91acfde/cache-121c4e7194a5c4ed.arrow

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

# %%
batch_size = 16
model_name = model_checkpoint.split("/")[-1]
args = Seq2SeqTrainingArguments(
    f"{model_name}-finetuned-{source_lang}-to-{target_lang}",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=1,
    predict_with_generate=True    
)
# Out:
# Using the `WAND_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
transformers.logging.set_verbosity_info()

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation.
# ***** Running training *****
#   Num examples = 378778
#   Num Epochs = 1
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 23674
#     <div>
#
#       <progress value='23674' max='23674' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23674/23674 50:24, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.239500</td>
#       <td>1.094333</td>
#       <td>38.772000</td>
#       <td>15.675300</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23000
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23000/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23000/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500
# Configuration saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/config.json
# Model weights saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/special_tokens_map.json
# Deleting older checkpoint [opus-mt-ko-en-finetuned-ko-to-en/checkpoint-22000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation.
# ***** Running Evaluation *****
#   Num examples = 1241
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=23674, training_loss=1.3147646559244517, metrics={'train_runtime': 3024.4674, 'train_samples_per_second': 125.238, 'train_steps_per_second': 7.827, 'total_flos': 2852578658746368.0, 'train_loss': 1.3147646559244517, 'epoch': 1.0})

# %%
# last checkpoint = checkpoint-23500
# checking the fine tuned model
from transformers import MarianMTModel, MarianTokenizer
src_text = ['My name is Sarah and I live in London']

trained_model_name = 'opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500'

# %%
tokenizer = MarianTokenizer.from_pretrained(trained_model_name)
print(tokenizer.supported_language_codes)
# Out:
# Didn't find file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/added_tokens.json. We won't load it.
# Didn't find file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/tokenizer.json. We won't load it.
# loading file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/source.spm
# loading file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/target.spm
# loading file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/vocab.json
# loading file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/tokenizer_config.json
# loading file None
# loading file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/special_tokens_map.json
# loading file None
# []

# %%
src_text = ['이 회사의 가치는 향후 20년 동안 기하적으로 급상승할 것이라고 전망이 됩니다.']
model = MarianMTModel.from_pretrained(model_name)
translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))
[tokenizer.decode(t, skip_special_tokens=True) for t in translated]
# Out:
# loading configuration file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/config.json
# Model config MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-ko-en",
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       65000
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 65000,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "extra_pos_embeddings": 65001,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 6,
#   "num_hidden_layers": 6,
#   "pad_token_id": 65000,
#   "scale_embedding": true,
#   "static_position_embeddings": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.15.0",
#   "use_cache": true,
#   "vocab_size": 65001
# }
#
# loading weights file opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500/pytorch_model.bin
# All model checkpoint weights were used when initializing MarianMTModel.
#
# All the weights of MarianMTModel were initialized from the model checkpoint at opus-mt-ko-en-finetuned-ko-to-en/checkpoint-23500.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use MarianMTModel for predictions without further training.
# ["The company's value is expected to rise exponentially over the next 20 years."]

# %%
import shutil
in_dir = r'/content/copy_runs'
out_dir = r'/content/drive/MyDrive/finetune_model_ko_en/final/runs'
for f in os.listdir(in_dir):
  new_file_dir = os.path.join(out_dir, f)
  shutil.copy(os.path.join(in_dir, f), new_file_dir)
#shutil.copy("//content/opus-mt-ko-en-finetuned-ko-to-en/runs/Jan13_17-03-35_7eabdf4415bb/events.out.tfevents.1642093454.7eabdf4415bb.73.0", "/content/copy_runs/events.out.tfevents.1642093454.7eabdf4415bb.73.0")
